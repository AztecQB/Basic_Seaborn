# %% [markdown]
# **Some quick transformations**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
nfl_df = pd.read_csv('C:\\Users\\miker\\Desktop\\Nfl_Data.csv')
nfl_df.head()
# Out:
#             Player  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT  Rate  1st  \
# 0      Jordan Love      1083      6.7  162   90   55.6   8    6  77.3   49
# 1  Jimmy Garoppolo      1079      7.3  147  100   68.0   7    8  82.6   54
# 2    Kenny Pickett      1027      6.5  159   95   59.8   5    4  78.8   39
# 3      Bryce Young       967      5.3  182  115   63.2   6    4  78.7   56
# 4     Daniel Jones       884      5.8  151  104   68.9   2    6  71.7   41
#
#    1st%  20+  40+  Lng  Sck  SckY
# 0  30.2   12    3   77   10    83
# 1  36.7    9    0   32    7    52
# 2  24.5   14    3   72   14   106
# 3  30.8    7    0   30   16   128
# 4  27.2    9    1   58   28   150

# %%
nfl_df.set_index('Player', inplace = True)
nfl_df.rename(columns={'Rate':'Pass_Rating'}, inplace = True)
nfl_df.tail()

## We changed the column name of 'Rate' to perhaps make things easier for casual fans. ##
## We also set our player to be our index. ##
# Out:
#                 Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT  Pass_Rating  1st  \
# Player
# Justin Fields       1201      7.4  162  100   61.7  11    6         91.6   55
# Geno Smith          1172      7.2  164  111   67.7   5    3         90.8   56
# Ryan Tannehill      1128      7.1  158   98   62.0   2    6         71.9   49
# Zach Wilson         1097      6.0  182  110   60.4   4    5         73.4   50
# Baker Mayfield      1088      6.7  162  106   65.4   7    3         91.3   54
#
#                 1st%  20+  40+  Lng  Sck  SckY
# Player
# Justin Fields   34.0   21    2   58   24   143
# Geno Smith      34.2   14    0   36   11    93
# Ryan Tannehill  31.0   17    4   70   19   135
# Zach Wilson     27.5   13    1   68   19   130
# Baker Mayfield  33.3   15    2   70    5    25

# %%
## Let's add a column for yards lost per sack taken. ##
## Because some of these values are 0 for sacks taken, and I didn't feel like .fillna was appropriate, I added a small value to sack total that gets rounded out. ##

nfl_df['Yds/Sck'] = nfl_df.apply(lambda x: round(x['SckY'] / (x['Sck'] +.0001),2), axis=1)
nfl_df.head()
# Out:
#                  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT  Pass_Rating  \
# Player
# Jordan Love          1083      6.7  162   90   55.6   8    6         77.3
# Jimmy Garoppolo      1079      7.3  147  100   68.0   7    8         82.6
# Kenny Pickett        1027      6.5  159   95   59.8   5    4         78.8
# Bryce Young           967      5.3  182  115   63.2   6    4         78.7
# Daniel Jones          884      5.8  151  104   68.9   2    6         71.7
#
#                  1st  1st%  20+  40+  Lng  Sck  SckY  Yds/Sck
# Player
# Jordan Love       49  30.2   12    3   77   10    83     8.30
# Jimmy Garoppolo   54  36.7    9    0   32    7    52     7.43
# Kenny Pickett     39  24.5   14    3   72   14   106     7.57
# Bryce Young       56  30.8    7    0   30   16   128     8.00
# Daniel Jones      41  27.2    9    1   58   28   150     5.36

# %%
nfl_df['Cmp'].describe()

## There are 2 outliers that are going to give us issues. Let's look closer. ##
# Out:
# count     50.000000
# mean      83.420000
# std       57.242089
# min        1.000000
# 25%       18.250000
# 50%      102.000000
# 75%      129.750000
# max      163.000000
# Name: Cmp, dtype: float64

# %%
nfl_df['Cmp'].nsmallest(2)

## These two players are not quarterbacks. They each have a long completion due to a trick play, let's drop them. ##
# Out:
# Player
# Keenan Allen    1
# Drake London    1
# Name: Cmp, dtype: int64

# %%
nfl_df.drop(nfl_df['Cmp'].nsmallest(2).index, inplace = True)
nfl_df['Cmp'].describe()

## The new lowest value of 3 is Mike White, a backup quarterback for the Dolphins. We will keep him in our data. ##
# Out:
# count     48.000000
# mean      86.854167
# std       55.811990
# min        2.000000
# 25%       22.750000
# 50%      105.000000
# 75%      130.500000
# max      163.000000
# Name: Cmp, dtype: float64

# %% [markdown]
# **Distribution plot**

# %%
sns.displot(nfl_df['Yds/Att'], kde = True)

## Distribution of yards per attempt with a probablity density function (pdf) ##

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x='Cmp %', y='Yds/Att', data=nfl_df, kind='reg')

## Joint regression plot of completion percent on yards/attempt. ##

# %% [markdown]
# **Pair Plot**

# %%
## Using a pairplot, we can see the data in each column as it relates to the other columns. ##

sns.pairplot(nfl_df)

# %%
## Let's load a new dataset from the ones that Seaborn provides that serves our purposes a little better. ##

tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **Bar Plot**

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)

## Basic bar plot with binary variable, with data aggregated based on standard deviation. ##
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# **Box Plot**

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

## Here, we create a boxplot of total bill by day, aggregated by gender. ##
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Regression Plot**

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o', '^'],
          scatter_kws={'s':100, 'linewidths':0.5, 'edgecolor':'w'})

## An example of a customized scatterplot with a regression line. ##

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df)

## Another way to look at the data, this time we run regressions based on time, and separate gender into their own columns. ##
